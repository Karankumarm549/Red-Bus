# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\m karan kumar\1jupyternotebook\redbus\venv\lib\site-packages (9.0.0)Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import mysql.connector
import numpy as npy

# %%
dfb1=pd.read_csv('buses_AP.csv')
dfb2=pd.read_csv('buses_R.csv')
dfb3=pd.read_csv('buses_T.csv')
dfb4=pd.read_csv('buses_UP.csv')
dfb5=pd.read_csv('buses_G.csv')
dfb6=pd.read_csv('buses_WB.csv')
dfb7=pd.read_csv('buses_KL.csv')
dfb8=pd.read_csv('buses_H.csv')
dfb9=pd.read_csv('buses_SB.csv')
dfb10=pd.read_csv('buses_AS.csv')

Al_df=pd.concat([dfb1,dfb2,dfb3,dfb4,dfb5,dfb6,dfb7,dfb8,dfb9,dfb10],ignore_index=True)

# %%
Al_df
# Out:
#                         Route_name  \
# 0          Hyderabad to Vijayawada
# 1          Hyderabad to Vijayawada
# 2          Hyderabad to Vijayawada
# 3          Hyderabad to Vijayawada
# 4          Hyderabad to Vijayawada
# ...                            ...
# 7053  Dibrugarh to North Lakhimpur
# 7054  Dibrugarh to North Lakhimpur
# 7055  Dibrugarh to North Lakhimpur
# 7056  Dibrugarh to North Lakhimpur
# 7057  Dibrugarh to North Lakhimpur
#
#                                              Route_link             Bus_name  \
# 0     https://www.redbus.in/bus-tickets/hyderabad-to...             FRESHBUS
# 1     https://www.redbus.in/bus-tickets/hyderabad-to...             FRESHBUS
# 2     https://www.redbus.in/bus-tickets/hyderabad-to...    IntrCity SmartBus
# 3     https://www.redbus.in/bus-tickets/hyderabad-to...  AdIntrCity SmartBus
# 4     https://www.redbus.in/bus-tickets/hyderabad-to...             FRESHBUS
# ...                                                 ...                  ...
# 7053  https://www.redbus.in/bus-tickets/dibrugarh-to...       BARBIE TRAVELS
# 7054  https://www.redbus.in/bus-tickets/dibrugarh-to...        Maa Jagadamba
# 7055  https://www.redbus.in/bus-tickets/dibrugarh-to...        Maa Jagadamba
# 7056  https://www.redbus.in/bus-tickets/dibrugarh-to...      Air Bus Travels
# 7057  https://www.redbus.in/bus-tickets/dibrugarh-to...      Air Bus Travels
#
#                              Bus_type Start_time Total_duration End_time  \
# 0           Electric A/C Seater (2+2)      06:25        05h 20m    11:45
# 1           Electric A/C Seater (2+2)      10:25        06h 35m    17:00
# 2                    AC Sleeper (2+1)      23:30        07h 15m    06:45
# 3          A/C Seater / Sleeper (2+1)      00:15        06h 10m    06:25
# 4           Electric A/C Seater (2+2)      23:20        06h 25m    05:45
# ...                               ...        ...            ...      ...
# 7053  NON A/C Hi-Tech Push Back (2+2)      15:30        04h 00m    19:30
# 7054       A/C Seater Push Back (2+2)      16:15        03h 15m    19:30
# 7055       A/C Seater Push Back (2+2)      16:20        03h 10m    19:30
# 7056      NON AC Seater / Sleeper 2+1      19:40        05h 20m    01:00
# 7057      NON AC Seater / Sleeper 2+1      21:15        04h 45m    02:00
#
#        Ratings    Price     Seats_Available
# 0     4.7\n396      374  25 Seats available
# 1     4.6\n352      374  39 Seats available
# 2     4.7\n181  INR 639  31 Seats available
# 3     4.3\n246  INR 359  30 Seats available
# 4     4.5\n500      500  35 Seats available
# ...        ...      ...                 ...
# 7053    4.0\n1  INR 240  40 Seats available
# 7054   4.1\n15  INR 240  41 Seats available
# 7055       3.9  INR 240  41 Seats available
# 7056    3.6\n8  INR 400  46 Seats available
# 7057    3.7\n4  INR 400  46 Seats available
#
# [7058 rows x 10 columns]

# %%
Al_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6240 entries, 0 to 7057
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Route_name       6240 non-null   object
#  1   Route_link       6240 non-null   object
#  2   Bus_name         6240 non-null   object
#  3   Bus_type         6240 non-null   object
#  4   Start_time       6240 non-null   object
#  5   Total_duration   6240 non-null   object
#  6   End_time         6240 non-null   object
#  7   Ratings          6240 non-null   float64
#  8   Price            6240 non-null   float64
#  9   Seats_Available  6240 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 536.2+ KB

# %%
#convert prices to numeric
Al_df["Price"]=Al_df["Price"].str.replace("INR","")
Al_df["Price"]=Al_df["Price"].astype(float)
Al_df["Price"].fillna(0)
# Out:
# 0       374.0
# 1       374.0
# 2       639.0
# 3       359.0
# 4       500.0
#         ...
# 7053    240.0
# 7054    240.0
# 7055    240.0
# 7056    400.0
# 7057    400.0
# Name: Price, Length: 7058, dtype: float64

# %%
print(Al_df.dtypes)
# Out:
# Route_name          object
# Route_link          object
# Bus_name            object
# Bus_type            object
# Start_time          object
# Total_duration      object
# End_time            object
# Ratings            float64
# Price              float64
# Seats_Available     object
# dtype: object

# %%
# Sample DataFrame for demonstration (you can replace this with your actual DataFrame)
#All_df = pd.DataFrame({"Ratings": ["New 5", "3", "New 2", None, "New 4", " ", "New 6", 7, 8.5]})

# Print original DataFrame
print("Original Ratings:")
print(Al_df["Ratings"])

# Step 1: Ensure all values in Ratings are converted to strings
Al_df["Ratings"] = Al_df["Ratings"].astype(str)
print("\nAfter converting to string:")
print(Al_df["Ratings"])

# Step 2: Replace "New" with an empty string
Al_df["Ratings"] = Al_df["Ratings"].str.replace("New", "", regex=False)
print("\nAfter replacing 'New':")
print(Al_df["Ratings"])

# Step 3: Strip whitespace from each element in the Series
Al_df["Ratings"] = Al_df["Ratings"].str.strip()
print("\nAfter stripping whitespace:")
print(Al_df["Ratings"])

# Step 4: Split and keep only the first part (if space-separated)
Al_df["Ratings"] = Al_df["Ratings"].str.split().str[0]
print("\nAfter splitting and keeping first part:")
print(Al_df["Ratings"])

# Step 5: Convert to numeric, coerce errors to NaN
Al_df["Ratings"] = pd.to_numeric(Al_df["Ratings"], errors='coerce')
print("\nAfter converting to numeric:")
print(Al_df["Ratings"])

# Step 6: Fill NaN values with 0
Al_df["Ratings"].fillna(0, inplace=True)
print("\nAfter filling NaN values with 0:")
print(Al_df["Ratings"])
# Out:
# Original Ratings:
# 0       4.7\n396
# 1       4.6\n352
# 2       4.7\n181
# 3       4.3\n246
# 4       4.5\n500
#           ...
# 7053      4.0\n1
# 7054     4.1\n15
# 7055         3.9
# 7056      3.6\n8
# 7057      3.7\n4
# Name: Ratings, Length: 7058, dtype: object
#
# After converting to string:
# 0       4.7\n396
# 1       4.6\n352
# 2       4.7\n181
# 3       4.3\n246
# 4       4.5\n500
#           ...
# 7053      4.0\n1
# 7054     4.1\n15
# 7055         3.9
# 7056      3.6\n8
# 7057      3.7\n4
# Name: Ratings, Length: 7058, dtype: object
#
# After replacing 'New':
# 0       4.7\n396
# 1       4.6\n352
# 2       4.7\n181
# 3       4.3\n246
# 4       4.5\n500
#           ...
# 7053      4.0\n1
# 7054     4.1\n15
# 7055         3.9
# 7056      3.6\n8
# 7057      3.7\n4
# Name: Ratings, Length: 7058, dtype: object
#
# After stripping whitespace:
# 0       4.7\n396
# 1       4.6\n352
# 2       4.7\n181
# 3       4.3\n246
# 4       4.5\n500
#           ...
# 7053      4.0\n1
# 7054     4.1\n15
# 7055         3.9
# 7056      3.6\n8
# 7057      3.7\n4
# Name: Ratings, Length: 7058, dtype: object
#
# After splitting and keeping first part:
# 0       4.7
# 1       4.6
# 2       4.7
# 3       4.3
# 4       4.5
#        ...
# 7053    4.0
# 7054    4.1
# 7055    3.9
# 7056    3.6
# 7057    3.7
# Name: Ratings, Length: 7058, dtype: object
#
# After converting to numeric:
# 0       4.7
# 1       4.6
# 2       4.7
# 3       4.3
# 4       4.5
#        ...
# 7053    4.0
# 7054    4.1
# 7055    3.9
# 7056    3.6
# 7057    3.7
# Name: Ratings, Length: 7058, dtype: float64
#
# After filling NaN values with 0:
# 0       4.7
# 1       4.6
# 2       4.7
# 3       4.3
# 4       4.5
#        ...
# 7053    4.0
# 7054    4.1
# 7055    3.9
# 7056    3.6
# 7057    3.7
# Name: Ratings, Length: 7058, dtype: float64
# C:\Users\M Karan kumar\AppData\Local\Temp\ipykernel_18304\1366871762.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Al_df["Ratings"].fillna(0, inplace=True)

# %%
path=r"C:\Users\M Karan kumar\1 Jupyter NoteBOOk\REDBUS\Al_df.csv"
Al_df.to_csv('Al_df.csv',index=False)

# %%
# Drop rows where bus_name is null
Al_df.dropna(subset=["Bus_name"], inplace=True)

# Optional: Check the shape of the DataFrame to see how many rows were dropped
print(f"Remaining rows after dropping null bus_name: {Al_df.shape[0]}")
# Out:
# Remaining rows after dropping null bus_name: 6269

# %%
# Count of null values in the bus_name column
null_count = Al_df["Bus_name"].isnull().sum()

print(f"Count of null values in 'Bus_name': {null_count}")
# Out:
# Count of null values in 'Bus_name': 789

# %%
# Count of null values in the bus_type column
null_count = Al_df["Bus_type"].isnull().sum()

print(f"Count of null values in 'Bus_type': {null_count}")
# Out:
# Count of null values in 'Bus_type': 29

# %%
# Drop rows where bus_type is null
Al_df.dropna(subset=["Bus_type"], inplace=True)

# Optional: Check the shape of the DataFrame to see how many rows were dropped
print(f"Remaining rows after dropping null bus_type: {Al_df.shape[0]}")
# Out:
# Remaining rows after dropping null bus_type: 6240

# %%
#sql connection
con=mysql.connector.connect(host="localhost", user="root", password="@Karan549",database="redbus_project")
my_cursor = con.cursor()
my_cursor.execute("CREATE DATABASE IF NOT EXISTS new_redbus")

# %%
# Table Creation
my_cursor.execute("""CREATE TABLE IF NOT EXISTS bus_details(
                  ID INT AUTO_INCREMENT PRIMARY KEY,
                  Route_name VARCHAR(255) NULL,
                  Route_link VARCHAR(255) NULL,
                  Bus_name VARCHAR(255) NOT NULL,
                  Bus_type VARCHAR(255) NOT NULL,
                  Start_time VARCHAR(255) NOT NULL,
                  Total_duration VARCHAR(255) NOT NULL,
                  End_time VARCHAR(255) NOT NULL,
                  Ratings Float NULL,
                  Price FLOAT NULL,
                  Seats_Available VARCHAR(255) NOT NULL
                  
                  
                  
                  )""")
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
# SQL query to insert data into bus_details table
insert_query = '''INSERT INTO bus_details(
                    Route_name,
                    Route_link,
                    Bus_name,
                    Bus_type,
                    Start_time,
                    Total_duration,
                    End_time,
                    Ratings,
                    Price,
                    Seats_Available)
                  VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
data = Al_df.values.tolist()

my_cursor.executemany(insert_query, data)

con.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully
